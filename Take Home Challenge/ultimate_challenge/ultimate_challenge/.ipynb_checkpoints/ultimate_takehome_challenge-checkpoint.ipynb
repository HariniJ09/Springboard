# %% [markdown]
# ### Import data and packages##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import calendar
from sklearn.impute import SimpleImputer
import seaborn as sns
from dateutil.relativedelta import relativedelta
from sklearn.preprocessing import StandardScaler
from collections import Counter
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
df_logins = pd.read_json('data/logins.json', convert_dates=True)

# %% [markdown]
# ## Part 1 - Exploratory Data Analysis ###

# %%
print(df_logins.head())
df_logins.info()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93142 entries, 0 to 93141
# Data columns (total 1 columns):
# login_time    93142 non-null datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 727.8 KB

# %%
df_logins.set_index('login_time',inplace=True)

# %% [markdown]
# No missing values. Let's aggregate on a 15-min time intervals

# %%
df_logins['15min_count'] = 0
df_logins = df_logins.resample('15T').count()
df_logins.reset_index(inplace=True)
df_logins.head()
# Out:
#            login_time  15min_count
# 0 1970-01-01 20:00:00            2
# 1 1970-01-01 20:15:00            6
# 2 1970-01-01 20:30:00            9
# 3 1970-01-01 20:45:00            7
# 4 1970-01-01 21:00:00            1

# %% [markdown]
# to visualize the underlying pattern, lets plot login_time vs count.

# %%
df_logins.set_index('login_time').plot()
plt.xlabel('login trend month wise')
plt.show()

# %% [markdown]
# The graph does show that March and April were the months that had the maximum login, but no further insights are gained from this. Let us breakdown the time on day/month/week basis

# %%
df_logins.head()
# Out:
#            login_time  15min_count
# 0 1970-01-01 20:00:00            2
# 1 1970-01-01 20:15:00            6
# 2 1970-01-01 20:30:00            9
# 3 1970-01-01 20:45:00            7
# 4 1970-01-01 21:00:00            1

# %%
df_logins['month']= df_logins.login_time.dt.month.apply(lambda x: calendar.month_abbr[x])
df_logins['day'] = df_logins.login_time.dt.dayofweek.apply(lambda x: calendar.day_abbr[x])
df_logins['hour'] = df_logins.login_time.dt.hour

# %%
df_logins.head()
# Out:
#            login_time  15min_count month  day  hour
# 0 1970-01-01 20:00:00            2   Jan  Thu    20
# 1 1970-01-01 20:15:00            6   Jan  Thu    20
# 2 1970-01-01 20:30:00            9   Jan  Thu    20
# 3 1970-01-01 20:45:00            7   Jan  Thu    20
# 4 1970-01-01 21:00:00            1   Jan  Thu    21

# %%
pd.pivot_table(values='15min_count', index=['hour'],aggfunc=np.sum, data=df_logins).plot(kind='bar',color='purple')
plt.title('User login hourwise')
plt.show()

# %% [markdown]
# Looks like most people are active between 11a-12p (lunch hour!) and between 6p-4a(after and before work).

# %%
pd.pivot_table(values='15min_count', index=['day'],aggfunc=np.sum, data=df_logins).plot(color='green')
plt.title('User login Daywise')

plt.show()

# %% [markdown]
# Users login most on Saturday and Sunday (Weekends) when they are not working(rather than on weekdays).

# %%
pd.pivot_table(values='15min_count', index=['month'],aggfunc=np.sum, data=df_logins).plot(kind='bar',color='orange')
plt.title('User login Monthwise')
plt.show()

# %% [markdown]
# The number of logins are really high in Mar which is start of Spring.

# %% [markdown]
# ## Part 2 - Experiment and metrics design ##

# %% [markdown]
# The neighboring cities of Gotham and Metropolis have complementary circadian rhythms: on
# weekdays, Ultimate Gotham is most active at night, and Ultimate Metropolis is most active
# during the day. On weekends, there is reasonable activity in both cities.
# However, a toll bridge, with a two­way toll, between the two cities causes driver partners to tend
# to be exclusive to each city. The Ultimate managers of city operations for the two cities have
# proposed an experiment to encourage driver partners to be available in both cities, by
# reimbursing all toll costs.
# 1. What would you choose as the key measure of success of this experiment in encouraging driver partners to serve both cities, and why would you choose this metric?
# ##### Solution: We need to see if reimbursing toll cost will actually improve the margin/popularity of Ultimate Service that can be measured  in terms of the following factors: - increased trip across tolls, less waiting time, higher frequency of service and increased number of ratings for any driver from a city by customers from the other city. #####
# 2. Describe a practical experiment you would design to compare the effectiveness of the proposed change in relation to the key measure of success. Please provide details on:
#
#     a. how you will implement the experiment -
# ##### Solution: We can have control group as drivers that are not reimbursed vs those reimbursed and compare the above factors to see if this affects the success of the service. We can divide the group in 50-50 and conduct the experiment. #####
#
#     b. what statistical test(s) you will conduct to verify the significance of the observation
# ##### Solution: A/B testing. Null hypothesis : reimbursing drivers the toll cost does not impact the margins of the company. #####
#
#     c. how you would interpret the results and provide recommendations to the city operations team along with any caveats.
# ##### Solution: If null hypothesis is rejected i.e reimbursing positively impacts the margins of the company. The caveat is  that - the sample is random and not representative of the population, so we cannot assume that recommendation is true for the population. #####

# %% [markdown]
# ### Part 3 ‑ Predictive modeling ###
# Ultimate is interested in predicting rider retention. To help explore this question, we have
# provided a sample dataset of a cohort of users who signed up for an Ultimate account in
# January 2014. The data was pulled several months later; we consider a user retained if they
# were “active” (i.e. took a trip) in the preceding 30 days.
# We would like you to use this data set to help understand what factors are the best predictors
# for retention, and offer suggestions to operationalize those insights to help Ultimate.
# The data is in the attached file ultimate_data_challenge.json. See below for a detailed
# description of the dataset. Please include any code you wrote for the analysis and delete the
# dataset when you have finished with the challenge.
#
# 1. Perform any cleaning, exploratory analysis, and/or visualizations to use the provided
# data for this analysis (a few sentences/plots describing your approach will suffice). What
# fraction of the observed users were retained?
# 2. Build a predictive model to help Ultimate determine whether or not a user will be active
# in their 6th month on the system. Discuss why you chose your approach, what
# alternatives you considered, and any concerns you have. How valid is your model?
# Include any key indicators of model performance.
# 3. Briefly discuss how Ultimate might leverage the insights gained from the model to
# improve its long­term rider retention (again, a few sentences will suffice).

# %% [markdown]
# #### Loading data####

# %%
#df_ulti = pd.read_json('data/ultimate_data_challenge.json', orient='records') : ValueError: Expected object or value
openfile = open('data/ultimate_data_challenge.json')
jsondata = json.load(openfile)
df_ulti = pd.DataFrame(jsondata)

# %%
df_ulti.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# ...

# %%
df_ulti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
# city                      50000 non-null object
# trips_in_first_30_days    50000 non-null int64
# signup_date               50000 non-null object
# avg_rating_of_driver      41878 non-null float64
# avg_surge                 50000 non-null float64
# last_trip_date            50000 non-null object
# phone                     49604 non-null object
# surge_pct                 50000 non-null float64
# ultimate_black_user       50000 non-null bool
# weekday_pct               50000 non-null float64
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      49799 non-null float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Data Wrangling/Cleaning ###

# %% [markdown]
# Let's convert the dates to datetime objects

# %% [markdown]
# There are 30 missing 'phone' numbers, lets see the maxium used phone type by city and generalize that to fill in the missing value for a city.

# %%
df_ulti.groupby(['city','phone'])['phone'].count()
#Looks like Iphone users exceed Apple users in all the cities.
# Out:
# city            phone
# Astapor         Android     5244
#                 iPhone     11169
# King's Landing  Android     2498
#                 iPhone      7568
# Winterfell      Android     7280
#                 iPhone     15845
# Name: phone, dtype: int64

# %%
df_ulti.phone = df_ulti.phone.astype('str')

# %%
df_ulti.phone.value_counts()
# Out:
# iPhone     34582
# Android    15022
# None         396
# Name: phone, dtype: int64

# %%
imp = SimpleImputer(missing_values='None', strategy="most_frequent")
df_ulti['phone'] = imp.fit_transform(df_ulti[['phone']].astype(str)).ravel()

# %%
df_ulti[['signup_date', 'last_trip_date']] = df_ulti[['signup_date', 'last_trip_date']].apply(pd.to_datetime)

# %%
df_ulti.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# ...

# %% [markdown]
# Let's impute the missing values of 'rating' using their mean rating values by 'city'

# %%
df_ulti.groupby('city')['avg_rating_of_driver'].mean()
# Out:
# city
# Astapor           4.630593
# King's Landing    4.706997
# Winterfell        4.532996
# Name: avg_rating_of_driver, dtype: float64

# %%
df_ulti.groupby('city')['avg_rating_by_driver'].mean()
# Out:
# city
# Astapor           4.798853
# King's Landing    4.853162
# Winterfell        4.730909
# Name: avg_rating_by_driver, dtype: float64

# %%
df_ulti['avg_rating_of_driver'] = df_ulti.avg_rating_of_driver.fillna(df_ulti.groupby('city')['avg_rating_of_driver'].mean().iloc[0])
df_ulti['avg_rating_by_driver'] = df_ulti.avg_rating_by_driver.fillna(df_ulti.groupby('city')['avg_rating_by_driver'].mean().iloc[0])

# %%
df_ulti.groupby('city')['avg_rating_of_driver'].mean()
# Out:
# city
# Astapor           4.630593
# King's Landing    4.697320
# Winterfell        4.549524
# Name: avg_rating_of_driver, dtype: float64

# %%
df_ulti.groupby('city')['avg_rating_by_driver'].mean()
# Out:
# city
# Astapor           4.798853
# King's Landing    4.852947
# Winterfell        4.731209
# Name: avg_rating_by_driver, dtype: float64

# %%
df_ulti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
# city                      50000 non-null object
# trips_in_first_30_days    50000 non-null int64
# signup_date               50000 non-null datetime64[ns]
# avg_rating_of_driver      50000 non-null float64
# avg_surge                 50000 non-null float64
# last_trip_date            50000 non-null datetime64[ns]
# phone                     50000 non-null object
# surge_pct                 50000 non-null float64
# ultimate_black_user       50000 non-null bool
# weekday_pct               50000 non-null float64
# avg_dist                  50000 non-null float64
# avg_rating_by_driver      50000 non-null float64
# dtypes: bool(1), datetime64[ns](2), float64(6), int64(1), object(2)
# memory usage: 4.2+ MB

# %% [markdown]
# No more missing values!

# %%
df_ulti.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# ...

# %%
last_log_date = df_ulti['last_trip_date'].dt.date
print("Last log date: {}".format(last_log_date.max()))

retention_users = df_ulti['last_trip_date'].dt.date >= (last_log_date.max() - relativedelta(days=+30))

df_retention_users = df_ulti.iloc[np.nonzero(retention_users)]
print("num of retention users: {}".format(df_retention_users.shape[0]))
df_ulti['retained'] = retention_users
# Out:
# Last log date: 2014-07-01
# num of retention users: 18804
# C:\Users\harid\.conda\envs\TestEnv\lib\site-packages\numpy\core\fromnumeric.py:61: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   return bound(*args, **kwds)

# %% [markdown]
# A user that would be active 6 months on the system

# %%
#encode target variable 'active' as true or false for last trip in June (6th month) or July (7th month)
df_ulti['active'] = [True if x.month >= 6 else False for x in df_ulti.last_trip_date]

# %%
df_ulti.retained.value_counts(), df_ulti.active.value_counts() # They look the same, lets skip 'active' columns
df_ulti.drop('active', axis =1, inplace=True)

# %% [markdown]
# ### Exploratory Data Analysis ###

# %%
df_ulti.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver  retained
# ...

# %%
df_ulti.city.value_counts()
# Out:
# Winterfell        23336
# Astapor           16534
# King's Landing    10130
# Name: city, dtype: int64

# %%
cols = list(df_ulti.columns)

# %%
#df[cat] = le.fit_transform(df[cat].astype(str))
cols
# Out:
# ['city',
#  'trips_in_first_30_days',
#  'signup_date',
#  'avg_rating_of_driver',
#  'avg_surge',
#  'last_trip_date',
#  'phone',
#  'surge_pct',
#  'ultimate_black_user',
#  'weekday_pct',
#  'avg_dist',
#  'avg_rating_by_driver',
#  'retained']

# %%
df_ulti.phone.value_counts()
# Out:
# iPhone     34978
# Android    15022
# Name: phone, dtype: int64

# %%
df_ulti.city = df_ulti.city.astype('category')
df_ulti.phone = df_ulti.phone.astype('category')

# %% [markdown]
# Univariate analysis

# %%
columns_plots = cols

def plot_distribution(dataset, cols=3, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = np.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if (dataset[column].dtype.name in ['category', np.bool]): #If Categorical feature
            g = sns.countplot(y=column, data=dataset, palette='Set3')
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=45)
        else: #Numerical
            g = sns.distplot(dataset[column], hist=False, kde_kws={'bw':0.1})
            plt.xticks(rotation=45)
    
plot_distribution(df_ulti[columns_plots],  cols=3, width=20, height=20, hspace=0.45, wspace=0.5)

# %% [markdown]
# Bi-variate Analysis

# %%
df_ulti.dtypes
# Out:
# city                            category
# trips_in_first_30_days             int64
# signup_date               datetime64[ns]
# avg_rating_of_driver             float64
# avg_surge                        float64
# last_trip_date            datetime64[ns]
# phone                           category
# surge_pct                        float64
# ultimate_black_user                 bool
# weekday_pct                      float64
# avg_dist                         float64
# avg_rating_by_driver             float64
# retained                            bool
# dtype: object

# %%
df_ulti.phone.value_counts()
# Out:
# iPhone     34978
# Android    15022
# Name: phone, dtype: int64

# %%
cat_cols = ['city','phone']

plt.style.use('seaborn-whitegrid')
for cat in cat_cols:
     plt.figure()
     sns.countplot(y=cat, hue='retained',data=df_ulti,palette='Set2')

# %%
df_ulti.phone.value_counts()
# Out:
# iPhone     34978
# Android    15022
# Name: phone, dtype: int64

# %% [markdown]
# 'Winterfell' seems to have more retained users and in general more subscribers. Similarly the

# %%
df_ulti.describe()
# Out:
#        trips_in_first_30_days  avg_rating_of_driver     avg_surge  \
# count            50000.000000          50000.000000  50000.000000
# mean                 2.278200              4.606275      1.074764
# std                  3.792684              0.565078      0.222336
# min                  0.000000              1.000000      1.000000
# 25%                  0.000000              4.500000      1.000000
# 50%                  1.000000              4.700000      1.000000
# 75%                  3.000000              5.000000      1.050000
# max                125.000000              5.000000      8.000000
#
#           surge_pct   weekday_pct      avg_dist  avg_rating_by_driver
# count  50000.000000  50000.000000  50000.000000          50000.000000
# mean       8.849536     60.926084      5.796827              4.778241
# std       19.958811     37.081503      5.707357              0.445755
# min        0.000000      0.000000      0.000000              1.000000
# ...

# %%
cont_cols = [col for col in df_ulti if df_ulti[col].dtype in ['int64','float64']]
cont_cols.append('retained')

# %%
sns.pairplot(df_ulti[cont_cols], diag_kind="kde",height=4);

# %% [markdown]
# #### Feature Encoding ####

# %% [markdown]
# Let's encode categoric columns using get_dummies

# %%
X = df_ulti.drop(columns = ['retained'])
y = df_ulti['retained']

# %%
X = pd.get_dummies(X, columns = cat_cols, prefix_sep='_', drop_first=True)
X = X.drop(columns= ['signup_date','last_trip_date'])

# %%
X.head()
# Out:
#    trips_in_first_30_days  avg_rating_of_driver  avg_surge  surge_pct  \
# 0                       4                   4.7       1.10       15.4
# 1                       0                   5.0       1.00        0.0
# 2                       3                   4.3       1.00        0.0
# 3                       9                   4.6       1.14       20.0
# 4                      14                   4.4       1.19       11.8
#
#    ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                 True         46.2      3.67                   5.0
# 1                False         50.0      8.26                   5.0
# 2                False        100.0      0.77                   5.0
# 3                 True         80.0      2.36                   4.9
# 4                False         82.4      3.13                   4.9
#
#    city_King's Landing  city_Winterfell  phone_iPhone
# 0                    1                0             1
# ...

# %%
X.shape
# Out:
# (50000, 11)

# %% [markdown]
# ### Feature Selection ###

# %%
#Create a correlation plot of both datasets.
corr_Xy = pd.concat([X,y], axis=1)

plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(25,10)) 

#plt.subplot(1, 2, 1)
# Generate a mask for the upper triangle
mask = np.zeros_like(corr_Xy.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr_Xy.corr(), 
            vmin=-1, vmax=1, 
            square=True, 
            cmap=sns.color_palette("BrBG", 100), 
            mask=mask, 
            linewidths=.5)
plt.title("Heatmap showing correlation amongst dependant and independant variables", size=13)
plt.show()

# %%
from sklearn.ensemble import ExtraTreesClassifier as et

# Using ExtraTrees classifier to gain an insight on Feature Importance
clf = et()
clf.fit(X, y)

plt.style.use('seaborn-whitegrid')
importance = clf.feature_importances_

#####
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importance)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%.2f)" % (f + 1, indices[f], importance[indices[f]]))

#####
df_importances = pd.DataFrame(importance, index=X.columns, columns=["Importance"])
df_importances.sort_values(by='Importance', ascending=True).plot(kind='barh', figsize=(20,len(importance)/2), color='green');
# Out:
# Feature ranking:
# 1. feature 6 (0.29)
# 2. feature 5 (0.15)
# 3. feature 7 (0.10)
# 4. feature 0 (0.10)
# 5. feature 1 (0.09)
# 6. feature 3 (0.07)
# 7. feature 8 (0.07)
# 8. feature 2 (0.05)
# 9. feature 10 (0.04)
# 10. feature 4 (0.04)
# 11. feature 9 (0.01)

# %% [markdown]
# We observe that :
# 1. Avg distanct is highly correlated to user retention. People that commute long distances (say to work) might tag on to the same rider for stability.
# 2. Similarly users that commute on weekdays particularly, are retained again, as explained above.
# 3. It is also incidental that the people adopted are the ones that have a consistent high ratings by the driver and have used more during the first month of sign-up.
# 4. The rest of the features in their decreasing importance are- surge_pct, phone used and the city from where they travel.

# %% [markdown]
# ### Predictive Modelling ###

# %%
df = X.join(y)
df.to_csv('data/to_model.csv')

# %%
df_final = df.copy()
seed= 36

# %%
cont_cols = ['trips_in_first_30_days',
 'avg_rating_of_driver',
 'avg_surge',
 'surge_pct',
 'weekday_pct',
 'avg_dist',
 'avg_rating_by_driver']

# %%
st_sc = StandardScaler()
df_final[cont_cols] = st_sc.fit_transform(df_final[cont_cols])

# %%
df_final.head()
# Out:
#    trips_in_first_30_days  avg_rating_of_driver  avg_surge  surge_pct  \
# 0                0.453984              0.165863   0.113506   0.328202
# 1               -0.600689              0.696768  -0.336268  -0.443394
# 2                0.190316             -0.542011  -0.336268  -0.443394
# 3                1.772325             -0.011106   0.293416   0.558679
# 4                3.090665             -0.365043   0.518303   0.147829
#
#    ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                 True    -0.397131 -0.372650              0.497495
# 1                False    -0.294653  0.431583              0.497495
# 2                False     1.053741 -0.880771              0.497495
# 3                 True     0.514383 -0.602181              0.273154
# 4                False     0.579106 -0.467266              0.273154
#
#    city_King's Landing  city_Winterfell  phone_iPhone  retained
# 0                    1                0             1      True
# ...

# %% [markdown]
# ### Train/Test split ###

# %%
target = df_final.retained.values
counter = Counter(target)
print(counter)
for k,v in counter.items():
  per = v / len(target) * 100
  print('Class=%d, Count=%d, Percentage=%.3f%%' % (k, v, per))
# Out:
# Counter({False: 31196, True: 18804})
# Class=1, Count=18804, Percentage=37.608%
# Class=0, Count=31196, Percentage=62.392%

# %%
# !pip install imblearn

# %%
import imblearn
from imblearn.over_sampling import SMOTE
print(imblearn.__version__)
# Out:
# 0.7.0

# %%
oversample = SMOTE(random_state=seed)

# %%
#!pip install imblearn -U
# Out:
# Requirement already up-to-date: imblearn in c:\users\harid\.conda\envs\testenv\lib\site-packages (0.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
X, y = oversample.fit_resample(X, y)
df_smote.head()
# Out:
#    trips_in_first_30_days  avg_rating_of_driver  avg_surge  surge_pct  \
# 0                       4                   4.7       1.10       15.4
# 1                       0                   5.0       1.00        0.0
# 2                       3                   4.3       1.00        0.0
# 3                       9                   4.6       1.14       20.0
# 4                      14                   4.4       1.19       11.8
#
#    ultimate_black_user  weekday_pct  avg_dist  avg_rating_by_driver  \
# 0                 True         46.2      3.67                   5.0
# 1                False         50.0      8.26                   5.0
# 2                False        100.0      0.77                   5.0
# 3                 True         80.0      2.36                   4.9
# 4                False         82.4      3.13                   4.9
#
#    city_King's Landing  city_Winterfell  phone_iPhone  retained
# 0                    1                0             1      True
# ...

# %%
target = df_smote.retained.values
counter = Counter(target)
print(counter)
for k,v in counter.items():
  per = v / len(target) * 100
  print('Class=%d, Count=%d, Percentage=%.3f%%' % (k, v, per))
# Out:
# Counter({True: 31196, False: 31196})
# Class=1, Count=31196, Percentage=50.000%
# Class=0, Count=31196, Percentage=50.000%

# %%
# from numpy import where

# for label, _ in counter.items():
#     row_ix = where(y == label)[0]
#     plt.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
# plt.legend()
# plt.show()

# %%
# split features and target into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.675, random_state = seed)

train_total = len(y_train)
print('Training Set\nTotal:\t\t{}'.format(train_total))

test_total = len(y_test)
print('Test Set\nTotal:\t\t{}'.format(test_total))
# Out:
# Training Set
# Total:		42114
# Test Set
# Total:		20278

# %%
# Machine learning 
from sklearn import datasets, model_selection, tree, preprocessing, metrics, linear_model
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso, SGDClassifier
#tree
import graphviz
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# Grid and Random Search
import scipy.stats as st
from scipy.stats import randint as sp_randint
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# Metrics
from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc

import time
import datetime

# %%
# calculate the fpr and tpr for all thresholds of the classification
def plot_roc_curve(y_test, preds):
    fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
    roc_auc = metrics.auc(fpr, tpr)
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([-0.01, 1.01])
    plt.ylim([-0.01, 1.01])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
# Function that runs the requested algorithm and returns the accuracy metrics
def fit_ml_algo(algo, X_train, y_train, X_test, y_test, cv):
    # One Pass
    model = algo.fit(X_train, y_train)
    test_pred = model.predict(X_test)
    if (isinstance(algo, (LogisticRegression, 
                          KNeighborsClassifier, 
                          GaussianNB, 
                          DecisionTreeClassifier, 
                          RandomForestClassifier,
                          GradientBoostingClassifier))):
        probs = model.predict_proba(X_test)[:,1]
    else:
        probs = "Not Available"
    acc = round(model.score(X_test, y_test) * 100, 2) 
    # CV 
    train_pred = model_selection.cross_val_predict(algo, 
                                                  X_train, 
                                                  y_train, 
                                                  cv=cv, 
                                                  n_jobs = -1)
    acc_cv = round(metrics.accuracy_score(y_train, train_pred) * 100, 2)
    return train_pred, test_pred, acc, acc_cv, probs

# %% [markdown]
# ### ML Modelling ###

# %% [markdown]
# ## Logistic Regression ##

# %%
def report(results, n_top=5):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
# Specify parameters and distributions to sample from
param_dist = {'penalty': ['l2', 'l1'], 
                         'class_weight': [None, 'balanced'],
                         'C': np.logspace(-20, 20, 10000), 
                         'intercept_scaling': np.logspace(-20, 20, 10000)}

# Run Randomized Search
n_iter_search = 10
lrc = LogisticRegression()
random_search = RandomizedSearchCV(lrc, 
                                   n_jobs=-1, 
                                   param_distributions=param_dist, 
                                   n_iter=n_iter_search)

start = time.time()
random_search.fit(X_train, y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))
report(random_search.cv_results_)
# Out:
# RandomizedSearchCV took 9.67 seconds for 10 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.683 (std: 0.007)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 5843548.69832365, 'class_weight': 'balanced', 'C': 269862857278.2288}
#
# Model with rank: 2
# Mean validation score: 0.554 (std: 0.001)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 5.121190569653321e-07, 'class_weight': 'balanced', 'C': 7.731946296133027e-18}
#
# Model with rank: 2
# Mean validation score: 0.554 (std: 0.001)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 1.4894204131109023e-10, 'class_weight': 'balanced', 'C': 2.7085900224044746e-13}
#
# Model with rank: 4
# Mean validation score: 0.552 (std: 0.002)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 1.2708971653659985e-19, 'class_weight': None, 'C': 3.476595113481131e-09}
#
# Model with rank: 5
# Mean validation score: 0.551 (std: 0.002)
# ...

# %%
# Logistic Regression
start_time = time.time()
train_pred_log, test_pred_log, acc_log, acc_cv_log, probs_log = fit_ml_algo(LogisticRegression(n_jobs = -1), 
                                                                 X_train, 
                                                                 y_train, 
                                                                 X_test, y_test,
                                                                 10)
log_time = (time.time() - start_time)

# %%
print("Accuracy: %s" % acc_log)
print("Accuracy CV 10-Fold: %s" % acc_cv_log)
print("Running Time: %s" % datetime.timedelta(seconds=log_time))
# Out:
# Accuracy: 68.85
# Accuracy CV 10-Fold: 68.25
# Running Time: 0:00:04.835590

# %%
print(metrics.classification_report(y_train, train_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.67      0.71      0.69     20998
#         True       0.69      0.65      0.67     21116
#
#     accuracy                           0.68     42114
#    macro avg       0.68      0.68      0.68     42114
# weighted avg       0.68      0.68      0.68     42114

# %%
print(metrics.classification_report(y_test, test_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.68      0.71      0.70     10198
#         True       0.70      0.66      0.68     10080
#
#     accuracy                           0.69     20278
#    macro avg       0.69      0.69      0.69     20278
# weighted avg       0.69      0.69      0.69     20278

# %%
plot_roc_curve(y_test, probs_log)

# %% [markdown]
# #### Decision Tree Classifier ####

# %%
start_time = time.time()

def fit_ml_algo_clf(algo, X_train, y_train, X_test, y_test, cv):
    # One Pass
    model = algo.fit(X_train, y_train)
    test_pred = model.predict(X_test)
    if (isinstance(algo, (LogisticRegression, 
                          KNeighborsClassifier, 
                          GaussianNB, 
                          DecisionTreeClassifier, 
                          RandomForestClassifier,
                          GradientBoostingClassifier))):
        probs = model.predict_proba(X_test)[:,1]
    else:
        probs = "Not Available"
    acc = round(model.score(X_test, y_test) * 100, 2) 
    # CV 
    train_pred = model_selection.cross_val_predict(algo, 
                                                  X_train, 
                                                  y_train, 
                                                  cv=cv, 
                                                  n_jobs = -1)
    acc_cv = round(metrics.accuracy_score(y_train, train_pred) * 100, 2)
    return train_pred, test_pred, acc, acc_cv, probs, model

train_pred_dt, test_pred_dt, acc_dt, acc_cv_dt, probs_dt, clf_obj = fit_ml_algo_clf(DecisionTreeClassifier(), 
                                                             X_train, 
                                                             y_train, 
                                                             X_test, y_test,
                                                             10)
dt_time = (time.time() - start_time)
print("Accuracy: %s" % acc_dt)
print("Accuracy CV 10-Fold: %s" % acc_cv_dt)
print("Running Time: %s" % datetime.timedelta(seconds=dt_time))
# Out:
# Accuracy: 73.92
# Accuracy CV 10-Fold: 73.69
# Running Time: 0:00:02.895461

# %%
print(metrics.classification_report(y_train, train_pred_dt))
print(metrics.classification_report(y_test, test_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.74      0.74      0.74     20998
#         True       0.74      0.74      0.74     21116
#
#     accuracy                           0.74     42114
#    macro avg       0.74      0.74      0.74     42114
# weighted avg       0.74      0.74      0.74     42114
#
#               precision    recall  f1-score   support
#
#        False       0.74      0.73      0.74     10198
#         True       0.73      0.75      0.74     10080
#
#     accuracy                           0.74     20278
#    macro avg       0.74      0.74      0.74     20278
# weighted avg       0.74      0.74      0.74     20278

# %%
plot_roc_curve(y_test, probs_dt)

# %% [markdown]
# ### Ensemble - RFT ###

# %%
def report(results, n_top=5):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
# Specify parameters and distributions to sample from
param_dist = {"max_depth": [10, None],
              "max_features": sp_randint(1, 11),
              "min_samples_split": sp_randint(2, 20),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Run Randomized Search
n_iter_search = 10
rfc = RandomForestClassifier(n_estimators=10)
random_search = RandomizedSearchCV(rfc, 
                                   n_jobs = -1, 
                                   param_distributions=param_dist, 
                                   n_iter=n_iter_search)

start = time.time()
random_search.fit(X_train, y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))
report(random_search.cv_results_)
# Out:
# RandomizedSearchCV took 26.40 seconds for 10 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.788 (std: 0.003)
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 6, 'min_samples_split': 4}
#
# Model with rank: 2
# Mean validation score: 0.788 (std: 0.005)
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 10, 'min_samples_split': 17}
#
# Model with rank: 3
# Mean validation score: 0.787 (std: 0.004)
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 7, 'min_samples_split': 17}
#
# Model with rank: 4
# Mean validation score: 0.787 (std: 0.003)
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 9, 'min_samples_split': 12}
#
# Model with rank: 5
# Mean validation score: 0.785 (std: 0.003)
# ...

# %%
start_time = time.time()
rfc = RandomForestClassifier(n_estimators=10, 
                             min_samples_leaf=2,
                             min_samples_split=17, 
                             criterion='gini', 
                             max_features=8)
train_pred_rf, test_pred_rf, acc_rf, acc_cv_rf, probs_rf = fit_ml_algo(rfc, 
                                                             X_train, 
                                                             y_train, 
                                                             X_test, y_test,
                                                             10)
rf_time = (time.time() - start_time)
print("Accuracy: %s" % acc_rf)
print("Accuracy CV 10-Fold: %s" % acc_cv_rf)
print("Running Time: %s" % datetime.timedelta(seconds=rf_time))
# Out:
# Accuracy: 79.12
# Accuracy CV 10-Fold: 78.86
# Running Time: 0:00:09.590219

# %%
print(metrics.classification_report(y_train, train_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.78      0.79      0.79     20998
#         True       0.79      0.78      0.79     21116
#
#     accuracy                           0.79     42114
#    macro avg       0.79      0.79      0.79     42114
# weighted avg       0.79      0.79      0.79     42114

# %%
print(metrics.classification_report(y_test, test_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.79      0.79     10198
#         True       0.79      0.79      0.79     10080
#
#     accuracy                           0.79     20278
#    macro avg       0.79      0.79      0.79     20278
# weighted avg       0.79      0.79      0.79     20278

# %%
plot_roc_curve(y_test, probs_rf)

# %% [markdown]
# ### Gradient Boosting Trees ###

# %%
start_time = time.time()
train_pred_gbt, test_pred_gbt, acc_gbt, acc_cv_gbt, probs_gbt = fit_ml_algo(GradientBoostingClassifier(), 
                                                                 X_train, 
                                                                 y_train, 
                                                                 X_test, y_test,                                                                            
                                                                 10)
gbt_time = (time.time() - start_time)
print("Accuracy: %s" % acc_gbt)
print("Accuracy CV 10-Fold: %s" % acc_cv_gbt)
print("Running Time: %s" % datetime.timedelta(seconds=gbt_time))
# Out:
# Accuracy: 79.58
# Accuracy CV 10-Fold: 79.28
# Running Time: 0:00:44.985482

# %%
print(metrics.classification_report(y_train, train_pred_gbt))
print(metrics.classification_report(y_test, test_pred_gbt))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.79      0.80      0.79     20998
#         True       0.80      0.78      0.79     21116
#
#     accuracy                           0.79     42114
#    macro avg       0.79      0.79      0.79     42114
# weighted avg       0.79      0.79      0.79     42114
#
#               precision    recall  f1-score   support
#
#        False       0.79      0.80      0.80     10198
#         True       0.80      0.79      0.79     10080
#
#     accuracy                           0.80     20278
#    macro avg       0.80      0.80      0.80     20278
# weighted avg       0.80      0.80      0.80     20278

# %%
plot_roc_curve(y_test, probs_gbt)

# %% [markdown]
# ### Results ###

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 
              'Random Forest', 
              'Decision Tree', 'Gradient Boosting Trees'],
    'Accuracy': [
        acc_log, 
        acc_rf, 
        acc_dt,
        acc_gbt
    ]})
models.sort_values(by='Accuracy', ascending=False)
# Out:
#                      Model  Accuracy
# 3  Gradient Boosting Trees     79.58
# 1            Random Forest     79.12
# 2            Decision Tree     73.92
# 0      Logistic Regression     68.85

# %% [markdown]
# 10 - Fold Cross-validation

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 
              'Random Forest', 
              'Decision Tree', 'Gradient Boosting Trees'],
    'Accuracy (10-fold CV)': [
        acc_cv_log, 
        acc_cv_rf, 
        acc_cv_dt,
        acc_cv_gbt
    ]})
models.sort_values(by='Accuracy (10-fold CV)', ascending=False)
# Out:
#                      Model  Accuracy (10-fold CV)
# 3  Gradient Boosting Trees                  79.28
# 1            Random Forest                  78.86
# 2            Decision Tree                  73.69
# 0      Logistic Regression                  68.25

# %% [markdown]
# ### 4. Conclusion ###
# We used 2 methods to visualize the importance correlation between features.
#
# Feature correlation : On visualizing the correlation between dependant and independent variables we observed
# avg_cnt and surge_cnt are highly correlated.
# the Ultimate_black_users (premium service) is related to the retention rate.
#
# Feature importance : We fit a Exra Tree classifier to the model to select the important features.
# From this we could see the rank of feature dependency/importance once we fit the model. We draw the follow conclusions:
# 1. Avg distanct is highly correlated to user retention. People that commute long distances (say to work) might tag on to the same rider for stability.
# 2. Similarly users that commute on weekdays particularly, are retained again, as explained above.
# 3. It is also incidental that the people adopted are the ones that have a consistent high ratings by the driver and have used more during the first month of sign-up.
# 4. The rest of the features in their decreasing importance are- surge_pct, phone used and the city from where they travel.
#
# We find that the model is imbalanced. We use SMOTE technique so we can make the binary classification data in equal proportion.
# For the model results, we obtain the best accuracy in the Gradient Boosting Trees model (Accuracy in 10-fold CV: 78.65). SMOTE technoque was used and we found the accuracy of: 79.28%.

# %% [markdown]
# ### Reference ###

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/
