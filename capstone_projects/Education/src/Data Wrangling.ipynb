# %% [markdown]
# ## 1. Data Wrangling##

# %% [markdown]
# - We will source all the data required for this project
# - Clean the data
#     1. Impute missing values.
#     2. Extract/Deduce interpretable features from existing columns.
#     3. Standardize the datat types.
#     4. Omit columns that are not usuable.

# %% [markdown]
# Index - https://caaspp-elpac.cde.ca.gov/caaspp/research_fixfileformatCAST19
# Understanding Scores - https://caaspp-elpac.cde.ca.gov/caaspp/UnderstandingCASTResults

# %%
import pandas as pd
import numpy as np
import re

# %%
na_values = ['n/a', 'na', '-', '*']

df_all  = pd.read_csv("../data/cast_ca2019_all_csv_v1.txt", parse_dates=True, na_values=na_values)
df_entities = pd.read_csv("../data/cast_ca2019entities_csv.txt", encoding='latin1', parse_dates=True, na_values=na_values)

# %%
print(df_all.shape)
df_all.head()
# Out:
# (986765, 29)
#    County Code  District Code  School Code  Filler  Test Year  Demographic ID  \
# 0            0              0            0     NaN       2019               1
# 1            0              0            0     NaN       2019               3
# 2            0              0            0     NaN       2019               4
# 3            0              0            0     NaN       2019               6
# 4            0              0            0     NaN       2019               7
#
#   Test Type  Total Number Tested at Entity Level and Demographic  \
# 0         X                                          1477006.0
# 1         X                                           752970.0
# 2         X                                           724036.0
# 3         X                                          1285057.0
# 4         X                                            67405.0
#
#    Total Number Tested at this Demographic with Valid Scores  Grade  ...  \
# 0                                          1474994.0              5  ...
# 1                                           751862.0              5  ...
# 2                                           723132.0              5  ...
# 3                                          1283476.0              5  ...
# 4                                            67369.0              5  ...
#
#    Total Number of Students with Valid Scores  \
# 0                                    456221.0
# 1                                    234372.0
# 2                                    221849.0
# 3                                    368072.0
# 4                                     17976.0
#
#    Life Sciences Domain Percent Below Standard  \
# 0                                        45.09
# 1                                        45.64
# 2                                        44.51
# 3                                        36.81
# 4                                        20.08
#
#    Life Sciences Domain Percent Near Standard  \
# 0                                       42.59
# 1                                       41.96
# 2                                       43.26
# 3                                       48.15
# 4                                       51.35
#
#    Life Sciences Domain Percent Above Standard  \
# 0                                        12.32
# 1                                        12.40
# 2                                        12.23
# 3                                        15.04
# 4                                        28.57
#
#    Physical Sciences Domain Percent Below Standard  \
# 0                                            44.12
# 1                                            45.70
# 2                                            42.45
# 3                                            35.78
# 4                                            18.92
#
#    Physical Sciences Domain Percent Near Standard  \
# 0                                           41.58
# 1                                           39.76
# 2                                           43.49
# 3                                           46.74
# 4                                           46.77
#
#    Physical Sciences Domain Percent Above Standard  \
# 0                                            14.30
# 1                                            14.53
# 2                                            14.06
# 3                                            17.48
# 4                                            34.31
#
#    Earth and Space Sciences Domain Percent Below Standard  \
# 0                                              41.61
# 1                                              43.15
# 2                                              39.98
# 3                                              33.50
# 4                                              17.49
#
#    Earth and Space Sciences Domain Percent Near Standard  \
# 0                                              46.71
# 1                                              45.53
# 2                                              47.97
# 3                                              52.22
# 4                                              54.03
#
#    Earth and Space Sciences Domain Percent Above Standard
# 0                                              11.68
# 1                                              11.33
# 2                                              12.05
# 3                                              14.28
# 4                                              28.48
#
# [5 rows x 29 columns]

# %%
print(df_all['Test Type'].value_counts())
print(df_all['Test Year'].value_counts())
print(df_all['Test ID'].value_counts())
#Since these are same throughout, they can be deleted
# Out:
# X    986765
# Name: Test Type, dtype: int64
# 2019    986765
# Name: Test Year, dtype: int64
# 17    986765
# Name: Test ID, dtype: int64

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986765 entries, 0 to 986764
# Data columns (total 29 columns):
# County Code                                                  986765 non-null int64
# District Code                                                986765 non-null int64
# School Code                                                  986765 non-null int64
# Filler                                                       0 non-null float64
# Test Year                                                    986765 non-null int64
# Demographic ID                                               986765 non-null int64
# Test Type                                                    986765 non-null object
# Total Number Tested at Entity Level and Demographic          751470 non-null float64
# Total Number Tested at this Demographic with Valid Scores    751470 non-null float64
# Grade                                                        986765 non-null int64
# Test ID                                                      986765 non-null int64
# CAST Reported Enrollment                                     693722 non-null float64
# Total Number of Students Tested                              693722 non-null float64
# Mean Scale Score                                             292201 non-null float64
# Percentage Standard Exceeded                                 515806 non-null float64
# Percentage Standard Met                                      515806 non-null float64
# Percentage Standard Met and Above                            515806 non-null float64
# Percentage Standard Nearly Met                               515806 non-null float64
# Percentage Standard Not Met                                  515806 non-null float64
# Total Number of Students with Valid Scores                   693722 non-null float64
# Life Sciences Domain Percent Below Standard                  515806 non-null float64
# Life Sciences Domain Percent Near Standard                   515806 non-null float64
# Life Sciences Domain Percent Above Standard                  515806 non-null float64
# Physical Sciences Domain Percent Below Standard              515806 non-null float64
# Physical Sciences Domain Percent Near Standard               515806 non-null float64
# Physical Sciences Domain Percent Above Standard              515806 non-null float64
# Earth and Space Sciences Domain Percent Below Standard       515806 non-null float64
# Earth and Space Sciences Domain Percent Near Standard        515806 non-null float64
# Earth and Space Sciences Domain Percent Above Standard       515806 non-null float64
# dtypes: float64(21), int64(7), object(1)
# memory usage: 218.3+ MB

# %% [markdown]
# Since 'Test ID' is 17 which is 'Science' , 'Test Year' is 2019 and 'Test Type' is X which is science.

# %%
df_all.drop(columns=['Filler','Test Year','Test ID','Test Type'], inplace=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986765 entries, 0 to 986764
# Data columns (total 25 columns):
# County Code                                                  986765 non-null int64
# District Code                                                986765 non-null int64
# School Code                                                  986765 non-null int64
# Demographic ID                                               986765 non-null int64
# Total Number Tested at Entity Level and Demographic          751470 non-null float64
# Total Number Tested at this Demographic with Valid Scores    751470 non-null float64
# Grade                                                        986765 non-null int64
# CAST Reported Enrollment                                     693722 non-null float64
# Total Number of Students Tested                              693722 non-null float64
# Mean Scale Score                                             292201 non-null float64
# Percentage Standard Exceeded                                 515806 non-null float64
# Percentage Standard Met                                      515806 non-null float64
# Percentage Standard Met and Above                            515806 non-null float64
# Percentage Standard Nearly Met                               515806 non-null float64
# Percentage Standard Not Met                                  515806 non-null float64
# Total Number of Students with Valid Scores                   693722 non-null float64
# Life Sciences Domain Percent Below Standard                  515806 non-null float64
# Life Sciences Domain Percent Near Standard                   515806 non-null float64
# Life Sciences Domain Percent Above Standard                  515806 non-null float64
# Physical Sciences Domain Percent Below Standard              515806 non-null float64
# Physical Sciences Domain Percent Near Standard               515806 non-null float64
# Physical Sciences Domain Percent Above Standard              515806 non-null float64
# Earth and Space Sciences Domain Percent Below Standard       515806 non-null float64
# Earth and Space Sciences Domain Percent Near Standard        515806 non-null float64
# Earth and Space Sciences Domain Percent Above Standard       515806 non-null float64
# dtypes: float64(20), int64(5)
# memory usage: 188.2 MB

# %%
df_all[['Mean Scale Score','Percentage Standard Exceeded','Percentage Standard Met','Percentage Standard Met and Above','Percentage Standard Nearly Met','Percentage Standard Not Met']]
# Out:
#         Mean Scale Score  Percentage Standard Exceeded  \
# 0                  201.0                         11.98
# 1                  200.4                         12.01
# 2                  201.7                         11.95
# 3                  205.3                         14.72
# 4                  216.9                         31.37
# ...                  ...                           ...
# 986760               NaN                           NaN
# 986761               NaN                           NaN
# 986762               NaN                           NaN
# 986763               NaN                           NaN
# 986764               NaN                           NaN
#
#         Percentage Standard Met  Percentage Standard Met and Above  \
# 0                         19.74                              31.72
# 1                         19.28                              31.29
# 2                         20.22                              32.17
# 3                         23.66                              38.37
# 4                         29.47                              60.84
# ...                         ...                                ...
# 986760                      NaN                                NaN
# 986761                      NaN                                NaN
# 986762                      NaN                                NaN
# 986763                      NaN                                NaN
# 986764                      NaN                                NaN
#
#         Percentage Standard Nearly Met  Percentage Standard Not Met
# 0                                49.42                        18.86
# 1                                48.02                        20.68
# 2                                50.91                        16.93
# 3                                48.93                        12.70
# 4                                34.49                         4.67
# ...                                ...                          ...
# 986760                             NaN                          NaN
# 986761                             NaN                          NaN
# 986762                             NaN                          NaN
# 986763                             NaN                          NaN
# 986764                             NaN                          NaN
#
# [986765 rows x 6 columns]

# %%
df_all.isnull().sum()
# Out:
# County Code                                                       0
# District Code                                                     0
# School Code                                                       0
# Demographic ID                                                    0
# Total Number Tested at Entity Level and Demographic          235295
# Total Number Tested at this Demographic with Valid Scores    235295
# Grade                                                             0
# CAST Reported Enrollment                                     293043
# Total Number of Students Tested                              293043
# Mean Scale Score                                             694564
# Percentage Standard Exceeded                                 470959
# Percentage Standard Met                                      470959
# Percentage Standard Met and Above                            470959
# Percentage Standard Nearly Met                               470959
# Percentage Standard Not Met                                  470959
# Total Number of Students with Valid Scores                   293043
# Life Sciences Domain Percent Below Standard                  470959
# Life Sciences Domain Percent Near Standard                   470959
# Life Sciences Domain Percent Above Standard                  470959
# Physical Sciences Domain Percent Below Standard              470959
# Physical Sciences Domain Percent Near Standard               470959
# Physical Sciences Domain Percent Above Standard              470959
# Earth and Space Sciences Domain Percent Below Standard       470959
# Earth and Space Sciences Domain Percent Near Standard        470959
# Earth and Space Sciences Domain Percent Above Standard       470959
# dtype: int64

# %%
cols = list(df_all.columns.str.contains('Code|ID|Grade', regex=True))
df_all[df_all.columns[cols]] = df_all[df_all.columns[cols]].astype('category')

# %%
df_all.dtypes
# Out:
# County Code                                                  category
# District Code                                                category
# School Code                                                  category
# Demographic ID                                               category
# Total Number Tested at Entity Level and Demographic           float64
# Total Number Tested at this Demographic with Valid Scores     float64
# Grade                                                        category
# CAST Reported Enrollment                                      float64
# Total Number of Students Tested                               float64
# Mean Scale Score                                              float64
# Percentage Standard Exceeded                                  float64
# Percentage Standard Met                                       float64
# Percentage Standard Met and Above                             float64
# Percentage Standard Nearly Met                                float64
# Percentage Standard Not Met                                   float64
# Total Number of Students with Valid Scores                    float64
# Life Sciences Domain Percent Below Standard                   float64
# Life Sciences Domain Percent Near Standard                    float64
# Life Sciences Domain Percent Above Standard                   float64
# Physical Sciences Domain Percent Below Standard               float64
# Physical Sciences Domain Percent Near Standard                float64
# Physical Sciences Domain Percent Above Standard               float64
# Earth and Space Sciences Domain Percent Below Standard        float64
# Earth and Space Sciences Domain Percent Near Standard         float64
# Earth and Space Sciences Domain Percent Above Standard        float64
# dtype: object

# %%
df_entities.shape
# Out:
# (11182, 10)

# %%
df_entities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11182 entries, 0 to 11181
# Data columns (total 10 columns):
# County Code      11182 non-null int64
# District Code    11182 non-null int64
# School Code      11182 non-null int64
# Filler           0 non-null float64
# Test Year        11182 non-null int64
# Type ID          11182 non-null int64
# County Name      11182 non-null object
# District Name    11123 non-null object
# School Name      10099 non-null object
# Zip Code         11182 non-null object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 873.7+ KB

# %%
df_entities.head()
# Out:
#    County Code  District Code  School Code  Filler  Test Year  Type ID  \
# 0           37          68056       114686     NaN       2019        7
# 1           37          68056      6038111     NaN       2019        7
# 2           37          68056      6088983     NaN       2019        7
# 3           37          68056      6110696     NaN       2019        7
# 4           37          68056      6115620     NaN       2019        7
#
#   County Name             District Name                 School Name Zip Code
# 0   San Diego  Del Mar Union Elementary                   Ocean Air    92130
# 1   San Diego  Del Mar Union Elementary  Del Mar Heights Elementary    92014
# 2   San Diego  Del Mar Union Elementary    Del Mar Hills Elementary    92014
# 3   San Diego  Del Mar Union Elementary   Carmel Del Mar Elementary    92130
# 4   San Diego  Del Mar Union Elementary     Ashley Falls Elementary    92130

# %%
df_entities.drop(columns=['Filler','Test Year','Type ID'], inplace=True)

# %%
cat_cols = list(df_entities.columns.str.contains('Code|ID|Grade', regex=True))
df_entities[df_entities.columns[cat_cols]] = df_entities[df_entities.columns[cat_cols]].astype('category')
str_cols = list(df_entities.columns.str.contains('Name', regex=True))
df_entities[df_entities.columns[str_cols]] = df_entities[df_entities.columns[str_cols]].astype('str')

# %%
df_entities.dtypes
# Out:
# County Code      category
# District Code    category
# School Code      category
# County Name        object
# District Name      object
# School Name        object
# Zip Code         category
# dtype: object

# %%
df_entities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11182 entries, 0 to 11181
# Data columns (total 7 columns):
# County Code      11182 non-null category
# District Code    11182 non-null category
# School Code      11182 non-null category
# County Name      11182 non-null object
# District Name    11182 non-null object
# School Name      11182 non-null object
# Zip Code         11182 non-null category
# dtypes: category(4), object(3)
# memory usage: 840.2+ KB

# %% [markdown]
#     Loading the subgroups data to understand the ID

# %%
df_subgroups  = pd.read_csv("../data/Subgroups.txt", parse_dates=True, na_values=na_values, index_col='Demographic ID')

# %%
df_subgroups.drop(columns=['Demographic ID Num'], inplace=True)
df_subgroups.head()
# Out:
#                                           Demographic Name  \
# Demographic ID
# 1                                             All Students
# 3                                                     Male
# 4                                                   Female
# 6               Fluent English proficient and English only
# 7                 Initial fluent English proficient (IFEP)
#
#                            Student Group
# Demographic ID
# 1                           All Students
# 3                                 Gender
# 4                                 Gender
# 6               English-Language Fluency
# 7               English-Language Fluency

# %%
df_tests  = pd.read_csv("../data/Tests.txt", parse_dates=True, na_values=na_values, index_col='Test ID')

# %%
df_tests.drop(columns=['Test ID Num'], inplace=True)

# %%
df_tests.head()
# Out:
#                                     Test Name
# Test ID
# 1         SB - English Language Arts/Literacy
# 2                            SB - Mathematics
# 3        CAA - English Language Arts/Literacy
# 4                           CAA - Mathematics
# 17             CAST - California Science Test

# %% [markdown]
# Since we are considering just CAST (Science Test) this table is just for an info.

# %% [markdown]
# We will now use house prices from zillow to assign the median price of houses for a particular zipcode.

# %%
df_home_price = pd.read_csv("../data/Zillow_median_monthly_price.csv", na_values=na_values)

# %%
df_home_price.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    240227.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    209848.0  ...
# 2       New York-Newark-Jersey City  New York County    247618.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    200202.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    284312.0  ...
#
#    2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31  \
# 0   1263498.0   1258462.0   1255108.0   1237464.0   1213945.0   1184708.0
# 1    488603.0    487610.0    486842.0    486758.0    487956.0    489569.0
# 2   1156671.0   1159676.0   1179068.0   1198812.0   1212277.0   1212462.0
# 3    335844.0    335848.0    335952.0    335676.0    335851.0    336272.0
# 4    639873.0    638457.0    637151.0    636880.0    637169.0    637791.0
#
#    2020-04-30  2020-05-31  2020-06-30  2020-07-31
# 0   1172697.0   1163787.0   1161592.0   1163169.0
# 1    490612.0    490770.0    491112.0    492290.0
# 2   1222241.0   1227790.0   1233483.0   1236976.0
# 3    337283.0    338136.0    338624.0    338802.0
# 4    637309.0    636881.0    636623.0    637448.0
#
# [5 rows x 304 columns]

# %%
df_home_price.State.dtype
# Out:
# dtype('O')

# %%
df_home_price = df_home_price[df_home_price.State.str.contains('CA')]

# %%
print(df_home_price.RegionType.value_counts()), df_home_price.shape[0]
# Out:
# Zip    1685
# Name: RegionType, dtype: int64
# (None, 1685)

# %%
df_home_price.drop(columns=['SizeRank','RegionName','RegionType','StateName','State','Metro','CountyName','City'],inplace=True)

# %%
df_home_price.head()
# Out:
#     RegionID  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# 13     97564    330387.0    328880.0    328468.0    327403.0    327227.0
# 21     96107    170875.0    171206.0    171570.0    172226.0    172827.0
# 38     97771         NaN         NaN         NaN         NaN         NaN
# 42     96027    178004.0    178386.0    178126.0    177806.0    177327.0
# 86     97711    184135.0    183166.0    182891.0    182165.0    181979.0
#
#     1996-06-30  1996-07-31  1996-08-31  1996-09-30  ...  2019-10-31  \
# 13    326972.0    327140.0    327802.0    329051.0  ...   1183296.0
# 21    173253.0    173568.0    173630.0    173464.0  ...    658057.0
# 38         NaN         NaN         NaN         NaN  ...    586467.0
# 42    177019.0    177291.0    177304.0    177575.0  ...   1432077.0
# 86    181339.0    180736.0    180342.0    180366.0  ...   1050455.0
#
#     2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  \
# 13   1191693.0   1203702.0   1207570.0   1211730.0   1210772.0   1212158.0
# 21    660351.0    664511.0    668824.0    675012.0    680449.0    685447.0
# 38    586717.0    589478.0    588441.0    588778.0    590528.0    594184.0
# 42   1440036.0   1451605.0   1460735.0   1475234.0   1487485.0   1499307.0
# 86   1053680.0   1061628.0   1073929.0   1082567.0   1085791.0   1083617.0
#
#     2020-05-31  2020-06-30  2020-07-31
# 13   1207935.0   1202748.0   1200641.0
# 21    687374.0    689194.0    694206.0
# 38    594005.0    594274.0    595454.0
# 42   1506100.0   1512793.0   1522780.0
# 86   1078555.0   1074555.0   1071670.0
#
# [5 rows x 296 columns]

# %%
df_home_price.rename(columns={'RegionID':'Zip Code'}, inplace=True)

# %%
df_home_price.set_index('Zip Code', inplace=True)

# %%
df_home_price.columns = pd.to_datetime(df_home_price.columns)
df_2019_prices = df_home_price[[ y for y in df_home_price.columns if y.year == 2019]]

# %%
df_2019_prices
# Out:
#           2019-01-31  2019-02-28  2019-03-31  2019-04-30  2019-05-31  \
# Zip Code
# 97564      1181988.0   1181523.0   1180127.0   1173613.0   1177612.0
# 96107       649093.0    646361.0    644176.0    644193.0    648523.0
# 97771       591852.0    590413.0    588816.0    586887.0    588667.0
# 96027      1353884.0   1353547.0   1354847.0   1361135.0   1376452.0
# 97711      1015768.0   1010685.0   1013889.0   1022144.0   1032184.0
# ...              ...         ...         ...         ...         ...
# 97307        43614.0     43603.0     43595.0     43557.0     43448.0
# 98530       197599.0    197341.0    197421.0    196128.0    195670.0
# 98152       350419.0    353538.0    356945.0    358001.0    358245.0
# 98400       290410.0    292400.0    293567.0    292479.0    295928.0
# 98059       240631.0    241914.0    241698.0    239335.0    236714.0
#
#           2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  \
# Zip Code
# 97564      1182537.0   1185327.0   1180963.0   1178105.0   1183296.0
# 96107       653907.0    655255.0    654948.0    655326.0    658057.0
# 97771       589770.0    589269.0    587532.0    585711.0    586467.0
# 96027      1392587.0   1403224.0   1411147.0   1420920.0   1432077.0
# 97711      1041480.0   1046741.0   1044814.0   1047159.0   1050455.0
# ...              ...         ...         ...         ...         ...
# 97307        43337.0     42991.0     42617.0     42212.0     42057.0
# 98530       196711.0    200272.0    203531.0    205737.0    207472.0
# 98152       357564.0    353687.0    349208.0    344924.0    342777.0
# 98400       299763.0    304491.0    304312.0    301746.0    299198.0
# 98059       235240.0    235590.0    237160.0    237628.0    237913.0
#
#           2019-11-30  2019-12-31
# Zip Code
# 97564      1191693.0   1203702.0
# 96107       660351.0    664511.0
# 97771       586717.0    589478.0
# 96027      1440036.0   1451605.0
# 97711      1053680.0   1061628.0
# ...              ...         ...
# 97307        41931.0     41850.0
# 98530       209201.0    210799.0
# 98152       341630.0    340800.0
# 98400       296123.0    292129.0
# 98059       237357.0    236360.0
#
# [1685 rows x 12 columns]

# %% [markdown]
# We find the median across all the months of 2019

# %%
df_2019_prices['Median'] = df_2019_prices.median(axis=1, skipna=None)
# Out:
# C:\Users\harid\.conda\envs\TestEnv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019_prices = df_2019_prices['Median']

# %%
df_2019_prices = df_2019_prices.reset_index()

# %%
df_2019_prices.head()
# Out:
#    Zip Code     Median
# 0     97564  1181755.5
# 1     96107   654427.5
# 2     97771   588741.5
# 3     96027  1397905.5
# 4     97711  1043147.0

# %%
df_2019_prices.dtypes
# Out:
# Zip Code      int64
# Median      float64
# dtype: object

# %% [markdown]
# Let's now go ahead and join tables based on common columns.

# %% [markdown]
# ##### 1. Merging entities table with the grades table.

# %%
df_all.head()
# Out:
#   County Code District Code School Code Demographic ID  \
# 0           0             0           0              1
# 1           0             0           0              3
# 2           0             0           0              4
# 3           0             0           0              6
# 4           0             0           0              7
#
#    Total Number Tested at Entity Level and Demographic  \
# 0                                          1477006.0
# 1                                           752970.0
# 2                                           724036.0
# 3                                          1285057.0
# 4                                            67405.0
#
#    Total Number Tested at this Demographic with Valid Scores Grade  \
# 0                                          1474994.0             5
# 1                                           751862.0             5
# 2                                           723132.0             5
# 3                                          1283476.0             5
# 4                                            67369.0             5
#
#    CAST Reported Enrollment  Total Number of Students Tested  \
# 0                  463976.0                         456604.0
# 1                  238673.0                         234571.0
# 2                  225303.0                         222033.0
# 3                  374237.0                         368370.0
# 4                   18116.0                          17986.0
#
#    Mean Scale Score  ...  Total Number of Students with Valid Scores  \
# 0             201.0  ...                                    456221.0
# 1             200.4  ...                                    234372.0
# 2             201.7  ...                                    221849.0
# 3             205.3  ...                                    368072.0
# 4             216.9  ...                                     17976.0
#
#    Life Sciences Domain Percent Below Standard  \
# 0                                        45.09
# 1                                        45.64
# 2                                        44.51
# 3                                        36.81
# 4                                        20.08
#
#    Life Sciences Domain Percent Near Standard  \
# 0                                       42.59
# 1                                       41.96
# 2                                       43.26
# 3                                       48.15
# 4                                       51.35
#
#    Life Sciences Domain Percent Above Standard  \
# 0                                        12.32
# 1                                        12.40
# 2                                        12.23
# 3                                        15.04
# 4                                        28.57
#
#    Physical Sciences Domain Percent Below Standard  \
# 0                                            44.12
# 1                                            45.70
# 2                                            42.45
# 3                                            35.78
# 4                                            18.92
#
#    Physical Sciences Domain Percent Near Standard  \
# 0                                           41.58
# 1                                           39.76
# 2                                           43.49
# 3                                           46.74
# 4                                           46.77
#
#    Physical Sciences Domain Percent Above Standard  \
# 0                                            14.30
# 1                                            14.53
# 2                                            14.06
# 3                                            17.48
# 4                                            34.31
#
#    Earth and Space Sciences Domain Percent Below Standard  \
# 0                                              41.61
# 1                                              43.15
# 2                                              39.98
# 3                                              33.50
# 4                                              17.49
#
#    Earth and Space Sciences Domain Percent Near Standard  \
# 0                                              46.71
# 1                                              45.53
# 2                                              47.97
# 3                                              52.22
# 4                                              54.03
#
#    Earth and Space Sciences Domain Percent Above Standard
# 0                                              11.68
# 1                                              11.33
# 2                                              12.05
# 3                                              14.28
# 4                                              28.48
#
# [5 rows x 25 columns]

# %%
df_entities
# Out:
#       County Code District Code School Code County Name  \
# 0              37         68056      114686   San Diego
# 1              37         68056     6038111   San Diego
# 2              37         68056     6088983   San Diego
# 3              37         68056     6110696   San Diego
# 4              37         68056     6115620   San Diego
# ...           ...           ...         ...         ...
# 11177          37         68049      138313   San Diego
# 11178          37         68049     6038095   San Diego
# 11179          37         68049     6119564   San Diego
# 11180          37         68056           0   San Diego
# 11181          37         68056      110114   San Diego
#
#                   District Name                 School Name Zip Code
# 0      Del Mar Union Elementary                   Ocean Air    92130
# 1      Del Mar Union Elementary  Del Mar Heights Elementary    92014
# 2      Del Mar Union Elementary    Del Mar Hills Elementary    92014
# 3      Del Mar Union Elementary   Carmel Del Mar Elementary    92130
# 4      Del Mar Union Elementary     Ashley Falls Elementary    92130
# ...                         ...                         ...      ...
# 11177           University Prep             University Prep    91764
# 11178         Dehesa Elementary           Dehesa Elementary    92019
# 11179            Dehesa Charter              Dehesa Charter    92026
# 11180  Del Mar Union Elementary                         nan
# 11181  Del Mar Union Elementary              Sycamore Ridge    92130
#
# [11182 rows x 7 columns]

# %%
df_all.columns
# Out:
# Index(['County Code', 'District Code', 'School Code', 'Demographic ID',
#        'Total Number Tested at Entity Level and Demographic',
#        'Total Number Tested at this Demographic with Valid Scores', 'Grade',
#        'CAST Reported Enrollment', 'Total Number of Students Tested',
#        'Mean Scale Score', 'Percentage Standard Exceeded',
#        'Percentage Standard Met', 'Percentage Standard Met and Above',
#        'Percentage Standard Nearly Met', 'Percentage Standard Not Met',
#        'Total Number of Students with Valid Scores',
#        'Life Sciences Domain Percent Below Standard',
#        'Life Sciences Domain Percent Near Standard',
#        'Life Sciences Domain Percent Above Standard',
#        'Physical Sciences Domain Percent Below Standard',
#        'Physical Sciences Domain Percent Near Standard',
#        'Physical Sciences Domain Percent Above Standard',
#        'Earth and Space Sciences Domain Percent Below Standard',
#        'Earth and Space Sciences Domain Percent Near Standard',
#        'Earth and Space Sciences Domain Percent Above Standard'],
#       dtype='object')

# %%
grade_entities = pd.merge(df_all, df_entities, how='inner', on=['County Code','District Code','School Code'])

# %%
grade_entities.head()
# Out:
#   County Code District Code School Code Demographic ID  \
# 0           0             0           0              1
# 1           0             0           0              3
# 2           0             0           0              4
# 3           0             0           0              6
# 4           0             0           0              7
#
#    Total Number Tested at Entity Level and Demographic  \
# 0                                          1477006.0
# 1                                           752970.0
# 2                                           724036.0
# 3                                          1285057.0
# 4                                            67405.0
#
#    Total Number Tested at this Demographic with Valid Scores Grade  \
# 0                                          1474994.0             5
# 1                                           751862.0             5
# 2                                           723132.0             5
# 3                                          1283476.0             5
# 4                                            67369.0             5
#
#    CAST Reported Enrollment  Total Number of Students Tested  \
# 0                  463976.0                         456604.0
# 1                  238673.0                         234571.0
# 2                  225303.0                         222033.0
# 3                  374237.0                         368370.0
# 4                   18116.0                          17986.0
#
#    Mean Scale Score  ...  Physical Sciences Domain Percent Below Standard  \
# 0             201.0  ...                                            44.12
# 1             200.4  ...                                            45.70
# 2             201.7  ...                                            42.45
# 3             205.3  ...                                            35.78
# 4             216.9  ...                                            18.92
#
#    Physical Sciences Domain Percent Near Standard  \
# 0                                           41.58
# 1                                           39.76
# 2                                           43.49
# 3                                           46.74
# 4                                           46.77
#
#    Physical Sciences Domain Percent Above Standard  \
# 0                                            14.30
# 1                                            14.53
# 2                                            14.06
# 3                                            17.48
# 4                                            34.31
#
#    Earth and Space Sciences Domain Percent Below Standard  \
# 0                                              41.61
# 1                                              43.15
# 2                                              39.98
# 3                                              33.50
# 4                                              17.49
#
#    Earth and Space Sciences Domain Percent Near Standard  \
# 0                                              46.71
# 1                                              45.53
# 2                                              47.97
# 3                                              52.22
# 4                                              54.03
#
#    Earth and Space Sciences Domain Percent Above Standard  \
# 0                                              11.68
# 1                                              11.33
# 2                                              12.05
# 3                                              14.28
# 4                                              28.48
#
#            County Name  District Name  School Name  Zip Code
# 0  State of California            nan          nan
# 1  State of California            nan          nan
# 2  State of California            nan          nan
# 3  State of California            nan          nan
# 4  State of California            nan          nan
#
# [5 rows x 29 columns]

# %% [markdown]
# ##### 2. Merging the above table with home price table

# %%
df_2019_prices['Zip Code'] = df_2019_prices['Zip Code'].astype('str')

# %%
df_2019_prices.dtypes
# Out:
# Zip Code     object
# Median      float64
# dtype: object

# %%
grade_entities['Zip Code'] = grade_entities['Zip Code'].astype('str')

# %%
grade_entities.shape
# Out:
# (986765, 29)

# %%
df_geh= pd.merge(grade_entities, df_2019_prices, how='inner', on=['Zip Code'])

# %% [markdown]
# ##### 3. Merge with Subgroup ID Table

# %%
df_final = pd.merge(df_subgroups, df_geh, how='inner', on=['Demographic ID'])

# %%
df_final.head()
# Out:
#    Demographic ID Demographic Name Student Group County Code District Code  \
# 0               1     All Students  All Students           2         61333
# 1               1     All Students  All Students           2         61333
# 2               1     All Students  All Students           2         61333
# 3               1     All Students  All Students           6         10066
# 4               1     All Students  All Students           6         10066
#
#   School Code  Total Number Tested at Entity Level and Demographic  \
# 0     6002794                                               21.0
# 1     6002794                                               21.0
# 2     6002794                                               21.0
# 3      136580                                                NaN
# 4      136580                                                NaN
#
#    Total Number Tested at this Demographic with Valid Scores Grade  \
# 0                                               21.0             5
# 1                                               21.0             8
# 2                                               21.0            13
# 3                                                NaN             5
# 4                                                NaN             8
#
#    CAST Reported Enrollment  ...  \
# 0                      11.0  ...
# 1                      10.0  ...
# 2                      21.0  ...
# 3                       NaN  ...
# 4                       NaN  ...
#
#    Physical Sciences Domain Percent Near Standard  \
# 0                                           54.55
# 1                                             NaN
# 2                                           57.14
# 3                                             NaN
# 4                                             NaN
#
#    Physical Sciences Domain Percent Above Standard  \
# 0                                             9.09
# 1                                              NaN
# 2                                            14.29
# 3                                              NaN
# 4                                              NaN
#
#    Earth and Space Sciences Domain Percent Below Standard  \
# 0                                              36.36
# 1                                                NaN
# 2                                              33.33
# 3                                                NaN
# 4                                                NaN
#
#    Earth and Space Sciences Domain Percent Near Standard  \
# 0                                              63.64
# 1                                                NaN
# 2                                              42.86
# 3                                                NaN
# 4                                                NaN
#
#    Earth and Space Sciences Domain Percent Above Standard  County Name  \
# 0                                               0.00            Alpine
# 1                                                NaN            Alpine
# 2                                              23.81            Alpine
# 3                                                NaN            Colusa
# 4                                                NaN            Colusa
#
#                        District Name                School Name  Zip Code  \
# 0              Alpine County Unified  Diamond Valley Elementary     96120
# 1              Alpine County Unified  Diamond Valley Elementary     96120
# 2              Alpine County Unified  Diamond Valley Elementary     96120
# 3  Colusa County Office of Education             Coastal Buttes     95987
# 4  Colusa County Office of Education             Coastal Buttes     95987
#
#       Median
# 0  3042249.5
# 1  3042249.5
# 2  3042249.5
# 3   692087.0
# 4   692087.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Imputing Missing values

# %% [markdown]
# We can ignore the following columns:
# 'Mean value score'is a value that determines the 'Percentage Standard', which is already known so we can omit it.
# 'Total Number Tested/Valid Scores' can be ignored
# Percentage Standard Met and Above  is sum of  Percentage Standard Exceeded & Percentage Standard Met

# %%
df_final.isnull().sum()
# Out:
# Demographic ID                                                   0
# Demographic Name                                                 0
# Student Group                                                    0
# County Code                                                      0
# District Code                                                    0
# School Code                                                      0
# Total Number Tested at Entity Level and Demographic           5179
# Total Number Tested at this Demographic with Valid Scores     5179
# Grade                                                            0
# CAST Reported Enrollment                                      6852
# Total Number of Students Tested                               6852
# Mean Scale Score                                             12901
# Percentage Standard Exceeded                                 10312
# Percentage Standard Met                                      10312
# Percentage Standard Met and Above                            10312
# Percentage Standard Nearly Met                               10312
# Percentage Standard Not Met                                  10312
# Total Number of Students with Valid Scores                    6852
# Life Sciences Domain Percent Below Standard                  10312
# Life Sciences Domain Percent Near Standard                   10312
# Life Sciences Domain Percent Above Standard                  10312
# Physical Sciences Domain Percent Below Standard              10312
# Physical Sciences Domain Percent Near Standard               10312
# Physical Sciences Domain Percent Above Standard              10312
# Earth and Space Sciences Domain Percent Below Standard       10312
# Earth and Space Sciences Domain Percent Near Standard        10312
# Earth and Space Sciences Domain Percent Above Standard       10312
# County Name                                                      0
# District Name                                                    0
# School Name                                                      0
# Zip Code                                                         0
# Median                                                           0
# dtype: int64

# %%
df_final['School Name'].str.contains("Alternative" or "Program").any().sum()
# Out:
# 1

# %%
df_final.drop(columns=['Total Number Tested at Entity Level and Demographic', 'Total Number Tested at this Demographic with Valid Scores', 'CAST Reported Enrollment', 'Total Number of Students Tested','Mean Scale Score', 'Percentage Standard Met and Above'], inplace=True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16035 entries, 0 to 16034
# Data columns (total 26 columns):
# Demographic ID                                            16035 non-null int64
# Demographic Name                                          16035 non-null object
# Student Group                                             16035 non-null object
# County Code                                               16035 non-null category
# District Code                                             16035 non-null category
# School Code                                               16035 non-null category
# Grade                                                     16035 non-null category
# Percentage Standard Exceeded                              5723 non-null float64
# Percentage Standard Met                                   5723 non-null float64
# Percentage Standard Nearly Met                            5723 non-null float64
# Percentage Standard Not Met                               5723 non-null float64
# Total Number of Students with Valid Scores                9183 non-null float64
# Life Sciences Domain Percent Below Standard               5723 non-null float64
# Life Sciences Domain Percent Near Standard                5723 non-null float64
# Life Sciences Domain Percent Above Standard               5723 non-null float64
# Physical Sciences Domain Percent Below Standard           5723 non-null float64
# Physical Sciences Domain Percent Near Standard            5723 non-null float64
# Physical Sciences Domain Percent Above Standard           5723 non-null float64
# Earth and Space Sciences Domain Percent Below Standard    5723 non-null float64
# Earth and Space Sciences Domain Percent Near Standard     5723 non-null float64
# Earth and Space Sciences Domain Percent Above Standard    5723 non-null float64
# County Name                                               16035 non-null object
# District Name                                             16035 non-null object
# School Name                                               16035 non-null object
# Zip Code                                                  16035 non-null object
# Median                                                    16035 non-null float64
# dtypes: category(4), float64(15), int64(1), object(6)
# memory usage: 3.3+ MB

# %%
df_final[df_final.isnull().any(axis=1)].head()
# Out:
#    Demographic ID Demographic Name Student Group County Code District Code  \
# 1               1     All Students  All Students           2         61333
# 3               1     All Students  All Students           6         10066
# 4               1     All Students  All Students           6         10066
# 5               1     All Students  All Students           6         10066
# 6               1     All Students  All Students           6         10066
#
#   School Code Grade  Percentage Standard Exceeded  Percentage Standard Met  \
# 1     6002794     8                           NaN                      NaN
# 3      136580     5                           NaN                      NaN
# 4      136580     8                           NaN                      NaN
# 5      136580    13                           NaN                      NaN
# 6      630111     8                           NaN                      NaN
#
#    Percentage Standard Nearly Met  ...  \
# 1                             NaN  ...
# 3                             NaN  ...
# 4                             NaN  ...
# 5                             NaN  ...
# 6                             NaN  ...
#
#    Physical Sciences Domain Percent Near Standard  \
# 1                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
#
#    Physical Sciences Domain Percent Above Standard  \
# 1                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
#
#    Earth and Space Sciences Domain Percent Below Standard  \
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Earth and Space Sciences Domain Percent Near Standard  \
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Earth and Space Sciences Domain Percent Above Standard  County Name  \
# 1                                                NaN            Alpine
# 3                                                NaN            Colusa
# 4                                                NaN            Colusa
# 5                                                NaN            Colusa
# 6                                                NaN            Colusa
#
#                        District Name                School Name  Zip Code  \
# 1              Alpine County Unified  Diamond Valley Elementary     96120
# 3  Colusa County Office of Education             Coastal Buttes     95987
# 4  Colusa County Office of Education             Coastal Buttes     95987
# 5  Colusa County Office of Education             Coastal Buttes     95987
# 6  Colusa County Office of Education  S. William Abel Community     95987
#
#       Median
# 1  3042249.5
# 3   692087.0
# 4   692087.0
# 5   692087.0
# 6   692087.0
#
# [5 rows x 26 columns]

# %%
df = df_final.dropna(axis=0)

# %%
df.columns
# Out:
# Index(['Demographic ID', 'Demographic Name', 'Student Group', 'County Code',
#        'District Code', 'School Code', 'Grade', 'Percentage Standard Exceeded',
#        'Percentage Standard Met', 'Percentage Standard Nearly Met',
#        'Percentage Standard Not Met',
#        'Total Number of Students with Valid Scores',
#        'Life Sciences Domain Percent Below Standard',
#        'Life Sciences Domain Percent Near Standard',
#        'Life Sciences Domain Percent Above Standard',
#        'Physical Sciences Domain Percent Below Standard',
#        'Physical Sciences Domain Percent Near Standard',
#        'Physical Sciences Domain Percent Above Standard',
#        'Earth and Space Sciences Domain Percent Below Standard',
#        'Earth and Space Sciences Domain Percent Near Standard',
#        'Earth and Space Sciences Domain Percent Above Standard', 'County Name',
#        'District Name', 'School Name', 'Zip Code', 'Median'],
#       dtype='object')

# %% [markdown]
# We need to eliminate entries that are not schools. For eg anything with 'Program' or 'Alternative' in their title can be eliminated.

# %%
df = df[~df["School Name"].str.contains('Program|Alternative', case=False, na=False)]

# %% [markdown]
# We will save the final dataframe into a csv for futher processing.

# %%
df.to_csv('cleaned_school_df.csv', sep='\t')
